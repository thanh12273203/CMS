# %% [markdown]
# <a href="https://colab.research.google.com/github/ereinha/PMAE/blob/main/UCI_Higgs_Demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# # Uncomment this cell to store files to your personal google drive
# from google.colab import drive
# drive.mount('/content/drive')
# %cd drive/MyDrive

# %%
# !git clone https://github.com/ML4SCI/PMAE
# Out:
# Cloning into 'PMAE'...
# remote: Enumerating objects: 551, done.
# remote: Counting objects: 100% (207/207), done.
# remote: Compressing objects: 100% (106/106), done.
# remote: Total 551 (delta 123), reused 173 (delta 101), pack-reused 344
# Receiving objects: 100% (551/551), 8.82 MiB | 15.57 MiB/s, done.
# Resolving deltas: 100% (331/331), done.

# %%
# %cd PMAE
# Out:
# /content/PMAE

# %%
# !pwd
# Out:
# /content/PMAE

# %%
import train
import utils
import test_and_plot
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import json
from models import classifier, pmae
import torch
from torch import nn, optim
from torch.utils.data import DataLoader

# %%
# Download the files from UCI ML repository
# !wget https://archive.ics.uci.edu/ml/machine-learning-databases/00280/HIGGS.csv.gz
# !gzip -d HIGGS.csv.gz
# Out:
# --2023-09-25 23:27:39--  https://archive.ics.uci.edu/ml/machine-learning-databases/00280/HIGGS.csv.gz
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified
# Saving to: ‘HIGGS.csv.gz’
#
# HIGGS.csv.gz            [  <=>               ]   2.62G  22.6MB/s    in 2m 3s
#
# 2023-09-25 23:29:43 (21.9 MB/s) - ‘HIGGS.csv.gz’ saved [2816407858]

# %%
# Read in the csv
data = pd.read_csv('./HIGGS.csv', header=None)

# %%
# Split the data and labels
X = data.iloc[:,1:]
y = data.iloc[:,0]

# %%
# Get the inputs and outputs
X = np.array(X, dtype=np.float32)
y = np.array(y, dtype=np.float32)

# %%
# Grab only the first 1mil items
X = X[:1000000]
y = y[:1000000]

# %%
print(X.shape)
# Out:
# (1000000, 28)

# %%
# Remove high level features and add 0 padding to line up related quantities
X = np.delete(X, obj=np.s_[X.shape[1]-7:X.shape[1]], axis=-1)
X = np.insert(X, obj=np.s_[3:4], values=0, axis=-1)
X = np.insert(X, obj=np.s_[5:6], values=0, axis=-1)
X = np.insert(X, obj=np.s_[7:8], values=0, axis=-1)

# %%
# Visualizing the data
names = ["lepton pT", "lepton eta", "lepton phi", "Zero Padding",
         "missing energy magnitude", "Zero Padding", "missing energy phi", "Zero Padding",
         "jet 1 pt", "jet 1 eta", "jet 1 phi", "jet 1 b-tag",
         "jet 2 pt", "jet 2 eta", "jet 2 phi", "jet 2 b-tag",
         "jet 3 pt", "jet 3 eta", "jet 3 phi", "jet 3 b-tag",
         "jet 4 pt", "jet 4 eta", "jet 4 phi", "jet 4 b-tag"]

fig, axes = plt.subplots(6,4, figsize=(16,20))
fig.tight_layout(pad=4)

X_higgs = X[y==1]
X_nohiggs = X[y==0]
y_higgs = y[y==1]
y_nohiggs = y[y==0]

for i in range(len(axes)):
    for j in range(len(axes[0])):
        axes[i,j].hist(X_higgs[:,i*4+j], histtype='step', stacked=False, density=1, bins=30, label='Higgs')
        axes[i,j].hist(X_nohiggs[:,i*4+j], histtype='step', stacked=False, density=1, bins=30, label='Background')
        axes[i,j].set_title(names[i*4+j])
        axes[i,j].set_xlabel(names[i*4+j] + ' scaled')
        axes[i,j].legend()
        axes[i,j].set_ylabel("Proportion of data (density=1)")
plt.show()

# %%
del X
del y

# %%
print(len(X_higgs))
# Out:
# 529673

# %%
print(len(X_nohiggs))
# Out:
# 470327

# %%
labels_hh = np.ones(len(X_higgs))
labels_tt = np.zeros(len(X_nohiggs))

# %%
X_hh_train, X_val1, labels_hh_train, labels_val1 = train_test_split(X_higgs, labels_hh, test_size=0.2, random_state=42)
X_hh_val, X_hh_test, labels_hh_val, labels_hh_test = train_test_split(X_val1, labels_val1, test_size=0.5, random_state=42)

# %%
del X_higgs

# %%
# Normalize data
x_scaler = StandardScaler()
X_hh_train = x_scaler.fit_transform(X_hh_train)
X_hh_val = x_scaler.transform(X_hh_val)
X_hh_test = x_scaler.transform(X_hh_test)
X_nohiggs = x_scaler.transform(X_nohiggs)

# %%
X_tt_train, X_val1, labels_tt_train, labels_val1 = train_test_split(X_nohiggs, labels_tt, test_size=0.2, random_state=42)
X_tt_val, X_tt_test, labels_tt_val, labels_tt_test = train_test_split(X_val1, labels_val1, test_size=0.5, random_state=42)

# %%
del X_nohiggs

# %%
print(np.shape(X_hh_train), np.shape(X_tt_train))
# Out:
# (423738, 24) (376261, 24)

# %%
# Reshape from [N, F] -> [N, P, F] N=event num, F=features, P=particle/jet
X_hh_train = X_hh_train.reshape(X_hh_train.shape[0],6,4)
X_hh_val = X_hh_val.reshape(X_hh_val.shape[0],6,4)
X_hh_test = X_hh_test.reshape(X_hh_test.shape[0],6,4)
X_tt_train = X_tt_train.reshape(X_tt_train.shape[0],6,4)
X_tt_val = X_tt_val.reshape(X_tt_val.shape[0],6,4)
X_tt_test = X_tt_test.reshape(X_tt_test.shape[0],6,4)

phi_limit = np.max((abs(np.max(X_hh_train[:,0,2])), abs(np.min(X_hh_train[:,0,2])))) # Only need one value assuming phi distrubtions are all uniform
lower_pt_limit = [np.min(X_hh_train[:,i,0]) for i in range(6)]

# %%
def useful_b_tag(data):
    unique_values = np.unique(data)

    value_to_int = {value: i for i, value in enumerate(unique_values)}

    discretized_data = np.vectorize(value_to_int.__getitem__)(data)

    # initialize an empty array of shape (total_size, 2)
    new_array = np.zeros((len(discretized_data), 2))

    # fill the new array based on your conditions
    for i, val in enumerate(discretized_data):
        if val == 0:
            new_array[i] = [1, 0]
        elif val == 1:
            new_array[i] = [0.5, 0.5]
        else:
            new_array[i] = [0, 1]

    return new_array

# %%
def expand_and_append(array):
    array = np.append(array, np.zeros((array.shape[0], array.shape[1], 1)), axis=2)
    return array

# %%
# Apply b-tag modification to be a 2-class probability 1 -> [0, 1]; 0 -> [1, 0]; .5 -> [.5, .5]
X_hh_train = expand_and_append(X_hh_train)
X_hh_val = expand_and_append(X_hh_val)
X_hh_test = expand_and_append(X_hh_test)
X_tt_train = expand_and_append(X_tt_train)
X_tt_val = expand_and_append(X_tt_val)
X_tt_test = expand_and_append(X_tt_test)

for i in range(3,len(X_hh_train[0]),5):
    for j in range(6):
        X_hh_train[:,j,i:i+2] = useful_b_tag(X_hh_train[:,j,i])
        X_hh_val[:,j,i:i+2] = useful_b_tag(X_hh_val[:,j,i])
        X_hh_test[:,j,i:i+2] = useful_b_tag(X_hh_test[:,j,i])
        X_tt_train[:,j,i:i+2] = useful_b_tag(X_tt_train[:,j,i])
        X_tt_val[:,j,i:i+2] = useful_b_tag(X_tt_val[:,j,i])
        X_tt_test[:,j,i:i+2] = useful_b_tag(X_tt_test[:,j,i])

# %%
print(X_hh_train.shape)
# Out:
# (423738, 6, 5)

# %%
# Get weights for soft label focal loss
def get_f_alphas(arr):
    f_alphas = []
    for i in range(arr.shape[1]):
        temp_data = arr[:,i]
        temp_other_data = np.delete(arr, i, 1)
        len_neg = len(temp_data[temp_data == 0])
        pos_data = np.sum(temp_other_data, axis=1)
        len_pos = len(temp_data[temp_data == 1]) - len(temp_other_data[temp_other_data >= 2])/len(temp_other_data)
        f_alphas.append([len_pos/(len_pos+len_neg), len_neg/(len_neg+len_pos)])
    return f_alphas

# %%
f_alphas = (get_f_alphas(X_hh_train[:,:,4]))
f_alphas = np.array(f_alphas)

# %%
print(f_alphas)
# Out:
# [[0.         1.        ]
#  [0.         1.        ]
#  [0.45049583 0.54950417]
#  [0.42315248 0.57684752]
#  [0.37164203 0.62835797]
#  [0.3168511  0.6831489 ]]

# %%
f_alphas[:,1] *= 1. # Can use a number other than 1 to increase or decrease biasing toward underrepresented b-tag

# %%
names = ["lepton pT", "lepton eta", "lepton phi", "Padding", "Padding",
         "missing energy magnitude", "Padding", "missing energy phi", "Padding", "Padding",
         "jet 1 pt", "jet 1 eta", "jet 1 phi", "jet 1 b-tag-", "jet 1 b-tag+",
         "jet 2 pt", "jet 2 eta", "jet 2 phi", "jet 2 b-tag-", "jet 2 b-tag+",
         "jet 3 pt", "jet 3 eta", "jet 3 phi", "jet 3 b-tag-", "jet 3 b-tag+",
         "jet 4 pt", "jet 4 eta", "jet 4 phi", "jet 4 b-tag-", "jet 4 b-tag+",]

fig, axes = plt.subplots(6,5, figsize=(20,20))
fig.tight_layout(pad=4)

for i in range(len(axes)):
    for j in range(len(axes[0])):
        axes[i,j].hist(X_hh_train[:,i,j], histtype='step', stacked=False, density=1, bins=30, label='Higgs')
        axes[i,j].hist(X_tt_train[:,i,j], histtype='step', stacked=False, density=1, bins=30, label='Background')
        axes[i,j].set_title(names[i*5+j])
        axes[i,j].set_xlabel(names[i*5+j] + ' scaled')
        axes[i,j].legend()
        axes[i,j].set_ylabel("Proportion of data (density=1)")

# %%
X_train = np.append(X_hh_train, X_tt_train, axis=0)
del X_tt_train
X_val = np.append(X_hh_val, X_tt_val, axis=0)
del X_tt_val
X_test = np.append(X_hh_test, X_tt_test, axis=0)
del X_tt_test
labels_train = np.append(labels_hh_train, labels_tt_train, axis=0)
del labels_tt_train
labels_val = np.append(labels_hh_val, labels_tt_val, axis=0)
del labels_tt_val
labels_test = np.append(labels_hh_test, labels_tt_test, axis=0)
del labels_tt_test

# %%
# Replace with a saved model name you want to load from
resume = None

# %%
if resume is not None:
    # Load a config file from a json
    with open('/content/drive/MyDrive/PMAE/outputs/' + resume, 'r') as f:
        config = json.load(f)
else:
    # Load a config file from a json
    with open('./configs/uci_higgs_config_demo.json', 'r') as f:
        config = json.load(f)

# %%
model_name = (
    f'Model_DM{config["d_model"]}_H{config["num_heads"]}_L{config["num_layers"]}'
    f'_F{config["d_ff"]}_DR{config["dropout"]}_BS{config["batch_size"]}_T{config["test_batch_size"]}'
    f'_ANE{config["ae_num_epochs"]}_PNE{config["ae_num_epochs"]}_FNE{config["ae_num_epochs"]}'
    f'_AES{config["ae_epochs_to_saturate"]}_PES{config["pc_epochs_to_saturate"]}'
    f'_FES{config["fc_epochs_to_saturate"]}_IM{config["init_momentum"]}_MM{config["max_momentum"]}'
    f'_TILR{config["tae_init_lr"]}_PCLR{config["pc_init_lr"]}_FCLR{config["fc_init_lr"]}'
    f'_MSL{config["max_seq_len"]}_Mk{config["mask"]}_A{config["alpha"]}_B{config["beta"]}'
    f'_G{config["gamma"]}_D{config["delta"]}_OV{config["output_vars"]}_WD{config["weight_decay"]}'
    f'_MLR{config["min_lr"]}_ALD{config["ae_lr_decay"]}_PLD{config["pc_lr_decay"]}'
    f'_FLD{config["fc_lr_decay"]}_CIF{config["class_input_features"]}_CFD{config["class_ff_dim"]}'
)

# %%
# Set device to use gpu if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# Instantiate the dataset and DataLoader
train_data = utils.DataLabelDataset(X_train, labels_train)
train_loader = DataLoader(train_data, batch_size=config["batch_size"], drop_last=True, shuffle=True,
                          pin_memory=True, num_workers=2, pin_memory_device=str(device))
hh_train_data = utils.DataLabelDataset(X_hh_train, labels_hh_train)
hh_train_loader = DataLoader(hh_train_data, batch_size=config["batch_size"], drop_last=True, shuffle=True,
                             pin_memory=True, num_workers=2, pin_memory_device=str(device))
val_data = utils.DataLabelDataset(X_val, labels_val)
val_loader = DataLoader(val_data, batch_size=config["test_batch_size"], shuffle=True)
hh_val_data = utils.DataLabelDataset(X_hh_val, labels_hh_val)
hh_val_loader = DataLoader(hh_val_data, batch_size=config["test_batch_size"], shuffle=True)
test_data = utils.DataLabelDataset(X_test, labels_test)
test_loader = DataLoader(test_data, batch_size=config["test_batch_size"], shuffle=False)
del X_hh_train
del X_hh_val
del labels_hh_train
del labels_hh_val

# %%
# Build the autoencoder model
tae = pmae.TransformerAutoencoder(config['d_model'], config['num_heads'], config['num_layers'], config['d_ff'], config['max_seq_len'], config['output_vars'], config['dropout'], device)
# Build classifier
partial_class = classifier.BinaryClassifier(config['class_input_features'], config['class_ff_dim'], config['dropout'])
# Build classifier
full_class = classifier.BinaryClassifier(config['class_input_features'], config['class_ff_dim'], config['dropout'])

# %%
# Send the models to gpu if possible
tae = tae.to(device)
partial_class = partial_class.to(device)
full_class = full_class.to(device)

# %%
if resume is not None:
    try:
        tae.load_state_dict(torch.load('./saved_models/uci_higgs/TAE_best_' + model_name))
    except:
        print('No saved Autoencoder')
    try:
        partial_class.load_state_dict(torch.load('./saved_models/uci_higgs/Classifier_partial_best_' + model_name))
    except:
        print('No saved Partial Classifier')
    try:
        full_class.load_state_dict(torch.load('./saved_models/uci_higgs/Classifier_full_best_' + model_name))
    except:
        print('No saved Full Classifier')

# %%
# Assign the criterion
criterion = utils.custom_loss(phi_limit, config['alpha'], config['beta'], config['gamma'], config['delta'], lower_pt_limit, f_alphas, config['output_vars'])
criterion_2 = nn.BCELoss()

# %%
# Build the optimizers
optimizer = utils.SGDWithSaturatingMomentumAndDecay(tae.parameters(), lr=config['tae_init_lr'], momentum=config['init_momentum'], max_momentum=config['max_momentum'],
                                                    epochs_to_saturate=config['ae_epochs_to_saturate'], batches_per_epoch=len(hh_train_loader), weight_decay=0,
                                                    lr_decay=config['ae_lr_decay'], min_lr=config['min_lr'], resume_epoch=config['ae_resume_epoch'])
optimizer_2 = utils.SGDWithSaturatingMomentumAndDecay(partial_class.parameters(), lr=config['pc_init_lr'], momentum=config['init_momentum'],
                                                      max_momentum=config['max_momentum'],  epochs_to_saturate=config['pc_epochs_to_saturate'],
                                                      batches_per_epoch=len(train_loader), weight_decay=config['weight_decay'], lr_decay=config['pc_lr_decay'],
                                                      min_lr=config['min_lr'], resume_epoch=config['pc_resume_epoch'])
optimizer_3 = utils.SGDWithSaturatingMomentumAndDecay(full_class.parameters(), lr=config['fc_init_lr'], momentum=config['init_momentum'],
                                                      max_momentum=config['max_momentum'],  epochs_to_saturate=config['fc_epochs_to_saturate'],
                                                      batches_per_epoch=len(train_loader), weight_decay=config['weight_decay'], lr_decay=config['fc_lr_decay'],
                                                      min_lr=config['min_lr'], resume_epoch=config['fc_resume_epoch'])

# %%
# Train the autoencoder
val_loss_min = train.train(hh_train_loader, hh_val_loader, [tae], device, optimizer, criterion,
                           'autoencoder', config['output_vars'], zero_padded=[3,6,8], mask=config['mask'],
                           epochs=list(range(config['ae_resume_epoch'], config['ae_num_epochs'])),
                           save_path='./saved_models/uci_higgs', model_name=model_name)
# Out:
# Epoch [1/50], Batch [500/827], Loss: -0.1769
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/activation.py:1160: UserWarning: Converting mask without torch.bool dtype to bool; this will negatively affect performance. Prefer to use a boolean mask directly. (Triggered internally at ../aten/src/ATen/native/transformers/attention.cpp:150.)
#   return torch._native_multi_head_attention(
# Epoch [1/50], Val Loss: -0.2389
# Epoch [2/50], Batch [500/827], Loss: -0.2386
# Epoch [2/50], Val Loss: -0.2520
# Epoch [3/50], Batch [500/827], Loss: -0.2517
# Epoch [3/50], Val Loss: -0.2644
# Epoch [4/50], Batch [500/827], Loss: -0.2599
# Epoch [4/50], Val Loss: -0.2715
# Epoch [5/50], Batch [500/827], Loss: -0.2638
# Epoch [5/50], Val Loss: -0.2703
# Epoch [6/50], Batch [500/827], Loss: -0.2663
# Epoch [6/50], Val Loss: -0.2751
# Epoch [7/50], Batch [500/827], Loss: -0.2684
# Epoch [7/50], Val Loss: -0.2756
# Epoch [8/50], Batch [500/827], Loss: -0.2701
# Epoch [8/50], Val Loss: -0.2755
# Epoch [9/50], Batch [500/827], Loss: -0.2714
# Epoch [9/50], Val Loss: -0.2790
# Epoch [10/50], Batch [500/827], Loss: -0.2726
# Epoch [10/50], Val Loss: -0.2785
# Epoch [11/50], Batch [500/827], Loss: -0.2733
# Epoch [11/50], Val Loss: -0.2795
# Epoch [12/50], Batch [500/827], Loss: -0.2739
# Epoch [12/50], Val Loss: -0.2785
# Epoch [13/50], Batch [500/827], Loss: -0.2753
# Epoch [13/50], Val Loss: -0.2794
# Epoch [14/50], Batch [500/827], Loss: -0.2756
# Epoch [14/50], Val Loss: -0.2823
# Epoch [15/50], Batch [500/827], Loss: -0.2760
# Epoch [15/50], Val Loss: -0.2817
# Epoch [16/50], Batch [500/827], Loss: -0.2763
# Epoch [16/50], Val Loss: -0.2824
# Epoch [17/50], Batch [500/827], Loss: -0.2771
# Epoch [17/50], Val Loss: -0.2832
# Epoch [18/50], Batch [500/827], Loss: -0.2766
# Epoch [18/50], Val Loss: -0.2810
# Epoch [19/50], Batch [500/827], Loss: -0.2774
# Epoch [19/50], Val Loss: -0.2826
# Epoch [20/50], Batch [500/827], Loss: -0.2777
# Epoch [20/50], Val Loss: -0.2830
# Epoch [21/50], Batch [500/827], Loss: -0.2775
# Epoch [21/50], Val Loss: -0.2838
# Epoch [22/50], Batch [500/827], Loss: -0.2779
# Epoch [22/50], Val Loss: -0.2833
# Epoch [23/50], Batch [500/827], Loss: -0.2778
# Epoch [23/50], Val Loss: -0.2825
# Epoch [24/50], Batch [500/827], Loss: -0.2782
# Epoch [24/50], Val Loss: -0.2831
# Epoch [25/50], Batch [500/827], Loss: -0.2781
# Epoch [25/50], Val Loss: -0.2836
# Epoch [26/50], Batch [500/827], Loss: -0.2784
# Epoch [26/50], Val Loss: -0.2846
# Epoch [27/50], Batch [500/827], Loss: -0.2779
# Epoch [27/50], Val Loss: -0.2824
# Epoch [28/50], Batch [500/827], Loss: -0.2785
# Epoch [28/50], Val Loss: -0.2831
# Epoch [29/50], Batch [500/827], Loss: -0.2785
# Epoch [29/50], Val Loss: -0.2833
# Epoch [30/50], Batch [500/827], Loss: -0.2786
# Epoch [30/50], Val Loss: -0.2835
# Epoch [31/50], Batch [500/827], Loss: -0.2785
# Epoch [31/50], Val Loss: -0.2830
# Epoch [32/50], Batch [500/827], Loss: -0.2782
# Epoch [32/50], Val Loss: -0.2841
# Epoch [33/50], Batch [500/827], Loss: -0.2782
# Epoch [33/50], Val Loss: -0.2849
# Epoch [34/50], Batch [500/827], Loss: -0.2791
# Epoch [34/50], Val Loss: -0.2830
# Epoch [35/50], Batch [500/827], Loss: -0.2787
# Epoch [35/50], Val Loss: -0.2842
# Epoch [36/50], Batch [500/827], Loss: -0.2787
# Epoch [36/50], Val Loss: -0.2837
# Epoch [37/50], Batch [500/827], Loss: -0.2787
# Epoch [37/50], Val Loss: -0.2831
# Epoch [38/50], Batch [500/827], Loss: -0.2784
# Epoch [38/50], Val Loss: -0.2840
# Epoch [39/50], Batch [500/827], Loss: -0.2785
# Epoch [39/50], Val Loss: -0.2836
# Epoch [40/50], Batch [500/827], Loss: -0.2786
# Epoch [40/50], Val Loss: -0.2834
# Epoch [41/50], Batch [500/827], Loss: -0.2791
# Epoch [41/50], Val Loss: -0.2845
# Epoch [42/50], Batch [500/827], Loss: -0.2786
# Epoch [42/50], Val Loss: -0.2835
# Epoch [43/50], Batch [500/827], Loss: -0.2787
# Epoch [43/50], Val Loss: -0.2830
# Epoch [44/50], Batch [500/827], Loss: -0.2790
# Epoch [44/50], Val Loss: -0.2845
# Epoch [45/50], Batch [500/827], Loss: -0.2786
# Epoch [45/50], Val Loss: -0.2836
# Epoch [46/50], Batch [500/827], Loss: -0.2784
# Epoch [46/50], Val Loss: -0.2831
# Epoch [47/50], Batch [500/827], Loss: -0.2785
# Epoch [47/50], Val Loss: -0.2842
# Epoch [48/50], Batch [500/827], Loss: -0.2783
# Epoch [48/50], Val Loss: -0.2837
# Epoch [49/50], Batch [500/827], Loss: -0.2784
# Epoch [49/50], Val Loss: -0.2840
# Epoch [50/50], Batch [500/827], Loss: -0.2789
# Epoch [50/50], Val Loss: -0.2840

# %%
# Build the models and load saved weights
tae = pmae.TransformerAutoencoder(config['d_model'], config['num_heads'], config['num_layers'], config['d_ff'],
                                  config['max_seq_len'], config['output_vars'], config['dropout'], device)
tae.load_state_dict(torch.load('./saved_models/uci_higgs/TAE_best_' + model_name))
# Send the model to gpu if possible
tae = tae.to(device)
# Test the model and generate some plots
test_and_plot.test(test_loader, config['test_batch_size'], X_test, labels_test, names, [tae], device,
                   config['mask'], x_scaler, config['output_vars'], 'autoencoder', model_name)

# Note: zero-padded values aren't part of the loss function in this demo

# %%
# Build the autoencoder model
tae = pmae.TransformerAutoencoder(config['d_model'], config['num_heads'], config['num_layers'], config['d_ff'],
                                  config['max_seq_len'], config['output_vars'], config['dropout'], device)
tae.load_state_dict(torch.load('./saved_models/uci_higgs/TAE_best_' + model_name))
tae = tae.to(device)
for param in tae.parameters():
    param.requires_grad = False

# %%
# Train a partial-event classifier
val_loss_min = train.train(train_loader, val_loader, [tae, partial_class], device, optimizer_2, criterion_2,
                           'classifier partial', config['output_vars'], zero_padded=[3,6,8], mask=config['mask'],
                           epochs=list(range(config['pc_resume_epoch'], config['pc_num_epochs'])),
                           save_path='./saved_models/uci_higgs', model_name=model_name)
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/activation.py:1160: UserWarning: Converting mask without torch.bool dtype to bool; this will negatively affect performance. Prefer to use a boolean mask directly. (Triggered internally at ../aten/src/ATen/native/transformers/attention.cpp:150.)
#   return torch._native_multi_head_attention(
# Epoch [1/50], Batch [500/1562], Loss: 0.6674
# Epoch [1/50], Batch [1000/1562], Loss: 0.6469
# Epoch [1/50], Batch [1500/1562], Loss: 0.6363
# Epoch [1/50], Val Loss: 0.6316
# Epoch [2/50], Batch [500/1562], Loss: 0.6282
# Epoch [2/50], Batch [1000/1562], Loss: 0.6248
# Epoch [2/50], Batch [1500/1562], Loss: 0.6228
# Epoch [2/50], Val Loss: 0.6205
# Epoch [3/50], Batch [500/1562], Loss: 0.6173
# Epoch [3/50], Batch [1000/1562], Loss: 0.6162
# Epoch [3/50], Batch [1500/1562], Loss: 0.6166
# Epoch [3/50], Val Loss: 0.6100
# Epoch [4/50], Batch [500/1562], Loss: 0.6118
# Epoch [4/50], Batch [1000/1562], Loss: 0.6113
# Epoch [4/50], Batch [1500/1562], Loss: 0.6091
# Epoch [4/50], Val Loss: 0.6075
# Epoch [5/50], Batch [500/1562], Loss: 0.6076
# Epoch [5/50], Batch [1000/1562], Loss: 0.6070
# Epoch [5/50], Batch [1500/1562], Loss: 0.6056
# Epoch [5/50], Val Loss: 0.6032
# Epoch [6/50], Batch [500/1562], Loss: 0.6051
# Epoch [6/50], Batch [1000/1562], Loss: 0.6040
# Epoch [6/50], Batch [1500/1562], Loss: 0.6036
# Epoch [6/50], Val Loss: 0.6027
# Epoch [7/50], Batch [500/1562], Loss: 0.6010
# Epoch [7/50], Batch [1000/1562], Loss: 0.6018
# Epoch [7/50], Batch [1500/1562], Loss: 0.6012
# Epoch [7/50], Val Loss: 0.6057
# Epoch [8/50], Batch [500/1562], Loss: 0.5984
# Epoch [8/50], Batch [1000/1562], Loss: 0.5979
# Epoch [8/50], Batch [1500/1562], Loss: 0.5997
# Epoch [8/50], Val Loss: 0.5985
# Epoch [9/50], Batch [500/1562], Loss: 0.5970
# Epoch [9/50], Batch [1000/1562], Loss: 0.5963
# Epoch [9/50], Batch [1500/1562], Loss: 0.5961
# Epoch [9/50], Val Loss: 0.5977
# Epoch [10/50], Batch [500/1562], Loss: 0.5942
# Epoch [10/50], Batch [1000/1562], Loss: 0.5960
# Epoch [10/50], Batch [1500/1562], Loss: 0.5944
# Epoch [10/50], Val Loss: 0.5980
# Epoch [11/50], Batch [500/1562], Loss: 0.5923
# Epoch [11/50], Batch [1000/1562], Loss: 0.5929
# Epoch [11/50], Batch [1500/1562], Loss: 0.5920
# Epoch [11/50], Val Loss: 0.5943
# Epoch [12/50], Batch [500/1562], Loss: 0.5911
# Epoch [12/50], Batch [1000/1562], Loss: 0.5909
# Epoch [12/50], Batch [1500/1562], Loss: 0.5906
# Epoch [12/50], Val Loss: 0.5950
# Epoch [13/50], Batch [500/1562], Loss: 0.5899
# Epoch [13/50], Batch [1000/1562], Loss: 0.5898
# Epoch [13/50], Batch [1500/1562], Loss: 0.5896
# Epoch [13/50], Val Loss: 0.5940
# Epoch [14/50], Batch [500/1562], Loss: 0.5874
# Epoch [14/50], Batch [1000/1562], Loss: 0.5891
# Epoch [14/50], Batch [1500/1562], Loss: 0.5886
# Epoch [14/50], Val Loss: 0.5937
# Epoch [15/50], Batch [500/1562], Loss: 0.5869
# Epoch [15/50], Batch [1000/1562], Loss: 0.5875
# Epoch [15/50], Batch [1500/1562], Loss: 0.5884
# Epoch [15/50], Val Loss: 0.5959
# Epoch [16/50], Batch [500/1562], Loss: 0.5859
# Epoch [16/50], Batch [1000/1562], Loss: 0.5864
# Epoch [16/50], Batch [1500/1562], Loss: 0.5863
# Epoch [16/50], Val Loss: 0.5915
# Epoch [17/50], Batch [500/1562], Loss: 0.5859
# Epoch [17/50], Batch [1000/1562], Loss: 0.5854
# Epoch [17/50], Batch [1500/1562], Loss: 0.5860
# Epoch [17/50], Val Loss: 0.5870
# Epoch [18/50], Batch [500/1562], Loss: 0.5851
# Epoch [18/50], Batch [1000/1562], Loss: 0.5842
# Epoch [18/50], Batch [1500/1562], Loss: 0.5849
# Epoch [18/50], Val Loss: 0.5895
# Epoch [19/50], Batch [500/1562], Loss: 0.5856
# Epoch [19/50], Batch [1000/1562], Loss: 0.5840
# Epoch [19/50], Batch [1500/1562], Loss: 0.5856
# Epoch [19/50], Val Loss: 0.5913
# Epoch [20/50], Batch [500/1562], Loss: 0.5833
# Epoch [20/50], Batch [1000/1562], Loss: 0.5828
# Epoch [20/50], Batch [1500/1562], Loss: 0.5848
# Epoch [20/50], Val Loss: 0.5897
# Epoch [21/50], Batch [500/1562], Loss: 0.5828
# Epoch [21/50], Batch [1000/1562], Loss: 0.5850
# Epoch [21/50], Batch [1500/1562], Loss: 0.5832
# Epoch [21/50], Val Loss: 0.5914
# Epoch [22/50], Batch [500/1562], Loss: 0.5833
# Epoch [22/50], Batch [1000/1562], Loss: 0.5815
# Epoch [22/50], Batch [1500/1562], Loss: 0.5847
# Epoch [22/50], Val Loss: 0.5898
# Epoch [23/50], Batch [500/1562], Loss: 0.5834
# Epoch [23/50], Batch [1000/1562], Loss: 0.5838
# Epoch [23/50], Batch [1500/1562], Loss: 0.5815
# Epoch [23/50], Val Loss: 0.5920
# Epoch [24/50], Batch [500/1562], Loss: 0.5830
# Epoch [24/50], Batch [1000/1562], Loss: 0.5831
# Epoch [24/50], Batch [1500/1562], Loss: 0.5826
# Epoch [24/50], Val Loss: 0.5887
# Epoch [25/50], Batch [500/1562], Loss: 0.5826
# Epoch [25/50], Batch [1000/1562], Loss: 0.5823
# Epoch [25/50], Batch [1500/1562], Loss: 0.5829
# Epoch [25/50], Val Loss: 0.5888
# Epoch [26/50], Batch [500/1562], Loss: 0.5820
# Epoch [26/50], Batch [1000/1562], Loss: 0.5827
# Epoch [26/50], Batch [1500/1562], Loss: 0.5812
# Epoch [26/50], Val Loss: 0.5901
# Epoch [27/50], Batch [500/1562], Loss: 0.5820
# Epoch [27/50], Batch [1000/1562], Loss: 0.5826
# Epoch [27/50], Batch [1500/1562], Loss: 0.5825
# Epoch [27/50], Val Loss: 0.5901
# Epoch [28/50], Batch [500/1562], Loss: 0.5804
# Epoch [28/50], Batch [1000/1562], Loss: 0.5826
# Epoch [28/50], Batch [1500/1562], Loss: 0.5821
# Epoch [28/50], Val Loss: 0.5866
# Epoch [29/50], Batch [500/1562], Loss: 0.5825
# Epoch [29/50], Batch [1000/1562], Loss: 0.5811
# Epoch [29/50], Batch [1500/1562], Loss: 0.5815
# Epoch [29/50], Val Loss: 0.5904
# Epoch [30/50], Batch [500/1562], Loss: 0.5805
# Epoch [30/50], Batch [1000/1562], Loss: 0.5820
# Epoch [30/50], Batch [1500/1562], Loss: 0.5817
# Epoch [30/50], Val Loss: 0.5890
# Epoch [31/50], Batch [500/1562], Loss: 0.5816
# Epoch [31/50], Batch [1000/1562], Loss: 0.5811
# Epoch [31/50], Batch [1500/1562], Loss: 0.5833
# Epoch [31/50], Val Loss: 0.5890
# Epoch [32/50], Batch [500/1562], Loss: 0.5803
# Epoch [32/50], Batch [1000/1562], Loss: 0.5837
# Epoch [32/50], Batch [1500/1562], Loss: 0.5821
# Epoch [32/50], Val Loss: 0.5874
# Epoch [33/50], Batch [500/1562], Loss: 0.5807
# Epoch [33/50], Batch [1000/1562], Loss: 0.5829
# Epoch [33/50], Batch [1500/1562], Loss: 0.5818
# Epoch [33/50], Val Loss: 0.5881
# Epoch [34/50], Batch [500/1562], Loss: 0.5825
# Epoch [34/50], Batch [1000/1562], Loss: 0.5799
# Epoch [34/50], Batch [1500/1562], Loss: 0.5833
# Epoch [34/50], Val Loss: 0.5872
# Epoch [35/50], Batch [500/1562], Loss: 0.5822
# Epoch [35/50], Batch [1000/1562], Loss: 0.5808
# Epoch [35/50], Batch [1500/1562], Loss: 0.5820
# Epoch [35/50], Val Loss: 0.5898
# Epoch [36/50], Batch [500/1562], Loss: 0.5827
# Epoch [36/50], Batch [1000/1562], Loss: 0.5819
# Epoch [36/50], Batch [1500/1562], Loss: 0.5812
# Epoch [36/50], Val Loss: 0.5861
# Epoch [37/50], Batch [500/1562], Loss: 0.5825
# Epoch [37/50], Batch [1000/1562], Loss: 0.5803
# Epoch [37/50], Batch [1500/1562], Loss: 0.5821
# Epoch [37/50], Val Loss: 0.5874
# Epoch [38/50], Batch [500/1562], Loss: 0.5813
# Epoch [38/50], Batch [1000/1562], Loss: 0.5811
# Epoch [38/50], Batch [1500/1562], Loss: 0.5810
# Epoch [38/50], Val Loss: 0.5879
# Epoch [39/50], Batch [500/1562], Loss: 0.5804
# Epoch [39/50], Batch [1000/1562], Loss: 0.5831
# Epoch [39/50], Batch [1500/1562], Loss: 0.5813
# Epoch [39/50], Val Loss: 0.5907
# Epoch [40/50], Batch [500/1562], Loss: 0.5806
# Epoch [40/50], Batch [1000/1562], Loss: 0.5812
# Epoch [40/50], Batch [1500/1562], Loss: 0.5823
# Epoch [40/50], Val Loss: 0.5870
# Epoch [41/50], Batch [500/1562], Loss: 0.5821
# Epoch [41/50], Batch [1000/1562], Loss: 0.5807
# Epoch [41/50], Batch [1500/1562], Loss: 0.5811
# Epoch [41/50], Val Loss: 0.5878
# Epoch [42/50], Batch [500/1562], Loss: 0.5818
# Epoch [42/50], Batch [1000/1562], Loss: 0.5806
# Epoch [42/50], Batch [1500/1562], Loss: 0.5818
# Epoch [42/50], Val Loss: 0.5884
# Epoch [43/50], Batch [500/1562], Loss: 0.5813
# Epoch [43/50], Batch [1000/1562], Loss: 0.5832
# Epoch [43/50], Batch [1500/1562], Loss: 0.5807
# Epoch [43/50], Val Loss: 0.5871
# Epoch [44/50], Batch [500/1562], Loss: 0.5815
# Epoch [44/50], Batch [1000/1562], Loss: 0.5816
# Epoch [44/50], Batch [1500/1562], Loss: 0.5814
# Epoch [44/50], Val Loss: 0.5874
# Epoch [45/50], Batch [500/1562], Loss: 0.5815
# Epoch [45/50], Batch [1000/1562], Loss: 0.5822
# Epoch [45/50], Batch [1500/1562], Loss: 0.5802
# Epoch [45/50], Val Loss: 0.5899
# Epoch [46/50], Batch [500/1562], Loss: 0.5813
# Epoch [46/50], Batch [1000/1562], Loss: 0.5815
# Epoch [46/50], Batch [1500/1562], Loss: 0.5811
# Epoch [46/50], Val Loss: 0.5871
# Epoch [47/50], Batch [500/1562], Loss: 0.5802
# Epoch [47/50], Batch [1000/1562], Loss: 0.5814
# Epoch [47/50], Batch [1500/1562], Loss: 0.5818
# Epoch [47/50], Val Loss: 0.5891
# Epoch [48/50], Batch [500/1562], Loss: 0.5800
# Epoch [48/50], Batch [1000/1562], Loss: 0.5817
# Epoch [48/50], Batch [1500/1562], Loss: 0.5830
# Epoch [48/50], Val Loss: 0.5862
# Epoch [49/50], Batch [500/1562], Loss: 0.5808
# Epoch [49/50], Batch [1000/1562], Loss: 0.5814
# Epoch [49/50], Batch [1500/1562], Loss: 0.5815
# Epoch [49/50], Val Loss: 0.5865
# Epoch [50/50], Batch [500/1562], Loss: 0.5816
# Epoch [50/50], Batch [1000/1562], Loss: 0.5810
# Epoch [50/50], Batch [1500/1562], Loss: 0.5804
# Epoch [50/50], Val Loss: 0.5870

# %%
# Train a full event classifier
val_loss_min = train.train(train_loader, val_loader, [tae, full_class], device, optimizer_3, criterion_2,
                           'classifier full', config['output_vars'], zero_padded=[3,6,8], mask=config['mask'],
                           epochs=list(range(config['fc_resume_epoch'], config['fc_num_epochs'])),
                           save_path='./saved_models/uci_higgs', model_name=model_name)
# Out:
# Epoch [1/50], Batch [500/1562], Loss: 0.6551
# Epoch [1/50], Batch [1000/1562], Loss: 0.6282
# Epoch [1/50], Batch [1500/1562], Loss: 0.6151
# Epoch [1/50], Val Loss: 0.6060
# Epoch [2/50], Batch [500/1562], Loss: 0.6008
# Epoch [2/50], Batch [1000/1562], Loss: 0.5957
# Epoch [2/50], Batch [1500/1562], Loss: 0.5890
# Epoch [2/50], Val Loss: 0.5827
# Epoch [3/50], Batch [500/1562], Loss: 0.5795
# Epoch [3/50], Batch [1000/1562], Loss: 0.5779
# Epoch [3/50], Batch [1500/1562], Loss: 0.5754
# Epoch [3/50], Val Loss: 0.5749
# Epoch [4/50], Batch [500/1562], Loss: 0.5686
# Epoch [4/50], Batch [1000/1562], Loss: 0.5675
# Epoch [4/50], Batch [1500/1562], Loss: 0.5663
# Epoch [4/50], Val Loss: 0.5689
# Epoch [5/50], Batch [500/1562], Loss: 0.5591
# Epoch [5/50], Batch [1000/1562], Loss: 0.5608
# Epoch [5/50], Batch [1500/1562], Loss: 0.5588
# Epoch [5/50], Val Loss: 0.5666
# Epoch [6/50], Batch [500/1562], Loss: 0.5529
# Epoch [6/50], Batch [1000/1562], Loss: 0.5527
# Epoch [6/50], Batch [1500/1562], Loss: 0.5530
# Epoch [6/50], Val Loss: 0.5622
# Epoch [7/50], Batch [500/1562], Loss: 0.5449
# Epoch [7/50], Batch [1000/1562], Loss: 0.5473
# Epoch [7/50], Batch [1500/1562], Loss: 0.5476
# Epoch [7/50], Val Loss: 0.5585
# Epoch [8/50], Batch [500/1562], Loss: 0.5396
# Epoch [8/50], Batch [1000/1562], Loss: 0.5404
# Epoch [8/50], Batch [1500/1562], Loss: 0.5432
# Epoch [8/50], Val Loss: 0.5580
# Epoch [9/50], Batch [500/1562], Loss: 0.5344
# Epoch [9/50], Batch [1000/1562], Loss: 0.5358
# Epoch [9/50], Batch [1500/1562], Loss: 0.5374
# Epoch [9/50], Val Loss: 0.5568
# Epoch [10/50], Batch [500/1562], Loss: 0.5317
# Epoch [10/50], Batch [1000/1562], Loss: 0.5299
# Epoch [10/50], Batch [1500/1562], Loss: 0.5306
# Epoch [10/50], Val Loss: 0.5531
# Epoch [11/50], Batch [500/1562], Loss: 0.5253
# Epoch [11/50], Batch [1000/1562], Loss: 0.5268
# Epoch [11/50], Batch [1500/1562], Loss: 0.5258
# Epoch [11/50], Val Loss: 0.5569
# Epoch [12/50], Batch [500/1562], Loss: 0.5180
# Epoch [12/50], Batch [1000/1562], Loss: 0.5229
# Epoch [12/50], Batch [1500/1562], Loss: 0.5224
# Epoch [12/50], Val Loss: 0.5555
# Epoch [13/50], Batch [500/1562], Loss: 0.5146
# Epoch [13/50], Batch [1000/1562], Loss: 0.5186
# Epoch [13/50], Batch [1500/1562], Loss: 0.5181
# Epoch [13/50], Val Loss: 0.5532
# Epoch [14/50], Batch [500/1562], Loss: 0.5116
# Epoch [14/50], Batch [1000/1562], Loss: 0.5135
# Epoch [14/50], Batch [1500/1562], Loss: 0.5138
# Epoch [14/50], Val Loss: 0.5600
# Epoch [15/50], Batch [500/1562], Loss: 0.5081
# Epoch [15/50], Batch [1000/1562], Loss: 0.5085
# Epoch [15/50], Batch [1500/1562], Loss: 0.5116
# Epoch [15/50], Val Loss: 0.5557
# Epoch [16/50], Batch [500/1562], Loss: 0.5047
# Epoch [16/50], Batch [1000/1562], Loss: 0.5050
# Epoch [16/50], Batch [1500/1562], Loss: 0.5074
# Epoch [16/50], Val Loss: 0.5562
# Epoch [17/50], Batch [500/1562], Loss: 0.5012
# Epoch [17/50], Batch [1000/1562], Loss: 0.5020
# Epoch [17/50], Batch [1500/1562], Loss: 0.5037
# Epoch [17/50], Val Loss: 0.5598
# Epoch [18/50], Batch [500/1562], Loss: 0.4973
# Epoch [18/50], Batch [1000/1562], Loss: 0.5009
# Epoch [18/50], Batch [1500/1562], Loss: 0.5008
# Epoch [18/50], Val Loss: 0.5576
# Epoch [19/50], Batch [500/1562], Loss: 0.4961
# Epoch [19/50], Batch [1000/1562], Loss: 0.4958
# Epoch [19/50], Batch [1500/1562], Loss: 0.4986
# Epoch [19/50], Val Loss: 0.5599
# Epoch [20/50], Batch [500/1562], Loss: 0.4940
# Epoch [20/50], Batch [1000/1562], Loss: 0.4948
# Epoch [20/50], Batch [1500/1562], Loss: 0.4959
# Epoch [20/50], Val Loss: 0.5599
# Epoch [21/50], Batch [500/1562], Loss: 0.4922
# Epoch [21/50], Batch [1000/1562], Loss: 0.4920
# Epoch [21/50], Batch [1500/1562], Loss: 0.4948
# Epoch [21/50], Val Loss: 0.5591
# Epoch [22/50], Batch [500/1562], Loss: 0.4895
# Epoch [22/50], Batch [1000/1562], Loss: 0.4914
# Epoch [22/50], Batch [1500/1562], Loss: 0.4927
# Epoch [22/50], Val Loss: 0.5598
# Epoch [23/50], Batch [500/1562], Loss: 0.4883
# Epoch [23/50], Batch [1000/1562], Loss: 0.4887
# Epoch [23/50], Batch [1500/1562], Loss: 0.4908
# Epoch [23/50], Val Loss: 0.5609
# Epoch [24/50], Batch [500/1562], Loss: 0.4862
# Epoch [24/50], Batch [1000/1562], Loss: 0.4886
# Epoch [24/50], Batch [1500/1562], Loss: 0.4893
# Epoch [24/50], Val Loss: 0.5642
# Epoch [25/50], Batch [500/1562], Loss: 0.4874
# Epoch [25/50], Batch [1000/1562], Loss: 0.4869
# Epoch [25/50], Batch [1500/1562], Loss: 0.4872
# Epoch [25/50], Val Loss: 0.5624
# Epoch [26/50], Batch [500/1562], Loss: 0.4865
# Epoch [26/50], Batch [1000/1562], Loss: 0.4849
# Epoch [26/50], Batch [1500/1562], Loss: 0.4870
# Epoch [26/50], Val Loss: 0.5634
# Epoch [27/50], Batch [500/1562], Loss: 0.4828
# Epoch [27/50], Batch [1000/1562], Loss: 0.4856
# Epoch [27/50], Batch [1500/1562], Loss: 0.4859
# Epoch [27/50], Val Loss: 0.5650
# Epoch [28/50], Batch [500/1562], Loss: 0.4824
# Epoch [28/50], Batch [1000/1562], Loss: 0.4846
# Epoch [28/50], Batch [1500/1562], Loss: 0.4861
# Epoch [28/50], Val Loss: 0.5637
# Epoch [29/50], Batch [500/1562], Loss: 0.4816
# Epoch [29/50], Batch [1000/1562], Loss: 0.4842
# Epoch [29/50], Batch [1500/1562], Loss: 0.4852
# Epoch [29/50], Val Loss: 0.5632
# Epoch [30/50], Batch [500/1562], Loss: 0.4825
# Epoch [30/50], Batch [1000/1562], Loss: 0.4836
# Epoch [30/50], Batch [1500/1562], Loss: 0.4839
# Epoch [30/50], Val Loss: 0.5644
# Epoch [31/50], Batch [500/1562], Loss: 0.4829
# Epoch [31/50], Batch [1000/1562], Loss: 0.4814
# Epoch [31/50], Batch [1500/1562], Loss: 0.4837
# Epoch [31/50], Val Loss: 0.5666
# Epoch [32/50], Batch [500/1562], Loss: 0.4828
# Epoch [32/50], Batch [1000/1562], Loss: 0.4826
# Epoch [32/50], Batch [1500/1562], Loss: 0.4820
# Epoch [32/50], Val Loss: 0.5670
# Epoch [33/50], Batch [500/1562], Loss: 0.4812
# Epoch [33/50], Batch [1000/1562], Loss: 0.4814
# Epoch [33/50], Batch [1500/1562], Loss: 0.4837
# Epoch [33/50], Val Loss: 0.5665
# Epoch [34/50], Batch [500/1562], Loss: 0.4809
# Epoch [34/50], Batch [1000/1562], Loss: 0.4821
# Epoch [34/50], Batch [1500/1562], Loss: 0.4817
# Epoch [34/50], Val Loss: 0.5659
# Epoch [35/50], Batch [500/1562], Loss: 0.4806
# Epoch [35/50], Batch [1000/1562], Loss: 0.4816
# Epoch [35/50], Batch [1500/1562], Loss: 0.4829
# Epoch [35/50], Val Loss: 0.5641
# Epoch [36/50], Batch [500/1562], Loss: 0.4816
# Epoch [36/50], Batch [1000/1562], Loss: 0.4804
# Epoch [36/50], Batch [1500/1562], Loss: 0.4815
# Epoch [36/50], Val Loss: 0.5631
# Epoch [37/50], Batch [500/1562], Loss: 0.4814
# Epoch [37/50], Batch [1000/1562], Loss: 0.4817
# Epoch [37/50], Batch [1500/1562], Loss: 0.4821
# Epoch [37/50], Val Loss: 0.5675
# Epoch [38/50], Batch [500/1562], Loss: 0.4819
# Epoch [38/50], Batch [1000/1562], Loss: 0.4812
# Epoch [38/50], Batch [1500/1562], Loss: 0.4797
# Epoch [38/50], Val Loss: 0.5651
# Epoch [39/50], Batch [500/1562], Loss: 0.4803
# Epoch [39/50], Batch [1000/1562], Loss: 0.4817
# Epoch [39/50], Batch [1500/1562], Loss: 0.4818
# Epoch [39/50], Val Loss: 0.5654
# Epoch [40/50], Batch [500/1562], Loss: 0.4800
# Epoch [40/50], Batch [1000/1562], Loss: 0.4817
# Epoch [40/50], Batch [1500/1562], Loss: 0.4805
# Epoch [40/50], Val Loss: 0.5674
# Epoch [41/50], Batch [500/1562], Loss: 0.4795
# Epoch [41/50], Batch [1000/1562], Loss: 0.4815
# Epoch [41/50], Batch [1500/1562], Loss: 0.4814
# Epoch [41/50], Val Loss: 0.5614
# Epoch [42/50], Batch [500/1562], Loss: 0.4818
# Epoch [42/50], Batch [1000/1562], Loss: 0.4797
# Epoch [42/50], Batch [1500/1562], Loss: 0.4804
# Epoch [42/50], Val Loss: 0.5645
# Epoch [43/50], Batch [500/1562], Loss: 0.4804
# Epoch [43/50], Batch [1000/1562], Loss: 0.4805
# Epoch [43/50], Batch [1500/1562], Loss: 0.4812
# Epoch [43/50], Val Loss: 0.5650
# Epoch [44/50], Batch [500/1562], Loss: 0.4805
# Epoch [44/50], Batch [1000/1562], Loss: 0.4814
# Epoch [44/50], Batch [1500/1562], Loss: 0.4811
# Epoch [44/50], Val Loss: 0.5671
# Epoch [45/50], Batch [500/1562], Loss: 0.4821
# Epoch [45/50], Batch [1000/1562], Loss: 0.4799
# Epoch [45/50], Batch [1500/1562], Loss: 0.4808
# Epoch [45/50], Val Loss: 0.5697
# Epoch [46/50], Batch [500/1562], Loss: 0.4809
# Epoch [46/50], Batch [1000/1562], Loss: 0.4797
# Epoch [46/50], Batch [1500/1562], Loss: 0.4807
# Epoch [46/50], Val Loss: 0.5658
# Epoch [47/50], Batch [500/1562], Loss: 0.4807
# Epoch [47/50], Batch [1000/1562], Loss: 0.4800
# Epoch [47/50], Batch [1500/1562], Loss: 0.4813
# Epoch [47/50], Val Loss: 0.5673
# Epoch [48/50], Batch [500/1562], Loss: 0.4808
# Epoch [48/50], Batch [1000/1562], Loss: 0.4796
# Epoch [48/50], Batch [1500/1562], Loss: 0.4816
# Epoch [48/50], Val Loss: 0.5656
# Epoch [49/50], Batch [500/1562], Loss: 0.4820
# Epoch [49/50], Batch [1000/1562], Loss: 0.4786
# Epoch [49/50], Batch [1500/1562], Loss: 0.4808
# Epoch [49/50], Val Loss: 0.5663
# Epoch [50/50], Batch [500/1562], Loss: 0.4800
# Epoch [50/50], Batch [1000/1562], Loss: 0.4804
# Epoch [50/50], Batch [1500/1562], Loss: 0.4826
# Epoch [50/50], Val Loss: 0.5677

# %%
# Parse a json config interpretation from a model name string
config = utils.parse_model_name(model_name)

# %%
# Build partial event classifier
partial_class = classifier.BinaryClassifier(config['class_input_features'], config['class_ff_dim'], config['dropout'])
partial_class.load_state_dict(torch.load('./saved_models/uci_higgs/Classifier_partial_best_' + model_name))
# Send the model to gpu if possible
partial_class = partial_class.to(device)
# Test the model and generate some plots
test_and_plot.test(test_loader, config['test_batch_size'], X_test, labels_test, names, [tae, partial_class], device,
                   config['mask'], x_scaler, config['output_vars'], 'partial', model_name)

# Note: zero-padded values aren't part of the loss function in this demo
# Out:
# Classification Accuracy (masked  lepton ):  0.5879041209587904
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/activation.py:1160: UserWarning: Converting mask without torch.bool dtype to bool; this will negatively affect performance. Prefer to use a boolean mask directly. (Triggered internally at ../aten/src/ATen/native/transformers/attention.cpp:150.)
#   return torch._native_multi_head_attention(
# Classification Accuracy (masked  missing energy ):  0.6195138048619514
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/activation.py:1160: UserWarning: Converting mask without torch.bool dtype to bool; this will negatively affect performance. Prefer to use a boolean mask directly. (Triggered internally at ../aten/src/ATen/native/transformers/attention.cpp:150.)
#   return torch._native_multi_head_attention(
# Classification Accuracy (masked  jet 1 ):  0.6367936320636793
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/activation.py:1160: UserWarning: Converting mask without torch.bool dtype to bool; this will negatively affect performance. Prefer to use a boolean mask directly. (Triggered internally at ../aten/src/ATen/native/transformers/attention.cpp:150.)
#   return torch._native_multi_head_attention(
# Classification Accuracy (masked  jet 2 ):  0.6597234027659723
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/activation.py:1160: UserWarning: Converting mask without torch.bool dtype to bool; this will negatively affect performance. Prefer to use a boolean mask directly. (Triggered internally at ../aten/src/ATen/native/transformers/attention.cpp:150.)
#   return torch._native_multi_head_attention(
# Classification Accuracy (masked  jet 3 ):  0.6826031739682603
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/activation.py:1160: UserWarning: Converting mask without torch.bool dtype to bool; this will negatively affect performance. Prefer to use a boolean mask directly. (Triggered internally at ../aten/src/ATen/native/transformers/attention.cpp:150.)
#   return torch._native_multi_head_attention(
# Classification Accuracy (masked  jet 4 ):  0.7024429755702443

# %%
# Build full event classifier
full_class = classifier.BinaryClassifier(config['class_input_features'], config['class_ff_dim'], config['dropout'])
full_class.load_state_dict(torch.load('./saved_models/uci_higgs/Classifier_full_best_' + model_name))
# Send the model to gpu if possible
full_class = full_class.to(device)
# Test the model and generate some plots
test_and_plot.test(test_loader, config['test_batch_size'], X_test, labels_test, names, [tae, full_class], device,
                   config['mask'], x_scaler, config['output_vars'], 'full', model_name)

# Note: zero-padded values aren't part of the loss function in this demo
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/activation.py:1160: UserWarning: Converting mask without torch.bool dtype to bool; this will negatively affect performance. Prefer to use a boolean mask directly. (Triggered internally at ../aten/src/ATen/native/transformers/attention.cpp:150.)
#   return torch._native_multi_head_attention(
# Classification Accuracy (full-information):  0.7141428585714142
